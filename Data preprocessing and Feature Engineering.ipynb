# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\\Users\\shankar\\Downloads\\train.csv")

# %%
df
# Out:
#                                 customer_id              Name  age gender  \
# 0          fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1      fffe43004900440032003100300035003700       Traci Peery   32      F
# 2          fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3      fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4      fffe43004900440031003900350030003600      Meghan Kosak   31      F
# ...                                     ...               ...  ...    ...
# 36987  fffe43004900440035003500390036003100          Cuc Tarr   46      F
# 36988  fffe43004900440033003500380036003600    Jenni Stronach   29      F
# 36989      fffe4300490044003500330034003100     Luciana Kinch   23      F
# 36990  fffe43004900440031003200390039003000     Tawana Ardoin   53      M
# 36991  fffe43004900440033003600340034003200  Verlene Beaulieu   35      M
#
#       security_no region_category  membership_category joining_date  \
# ...

# %%
df.describe()
# Out:
#                 age  days_since_last_login  avg_time_spent  \
# count  36992.000000           36992.000000    36992.000000
# mean      37.118161             -41.915576      243.472334
# std       15.867412             228.819900      398.289149
# min       10.000000            -999.000000    -2814.109110
# 25%       23.000000               8.000000       60.102500
# 50%       37.000000              12.000000      161.765000
# 75%       51.000000              16.000000      356.515000
# max       64.000000              26.000000     3235.578521
#
#        avg_transaction_value  points_in_wallet  churn_risk_score
# count           36992.000000      33549.000000      36992.000000
# mean            29271.194003        686.882199          3.463397
# std             19444.806226        194.063624          1.409661
# min               800.460000       -760.661236         -1.000000
# 25%             14177.540000        616.150000          3.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36992 entries, 0 to 36991
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customer_id                   36992 non-null  object
#  1   Name                          36992 non-null  object
#  2   age                           36992 non-null  int64
#  3   gender                        36992 non-null  object
#  4   security_no                   36992 non-null  object
#  5   region_category               31564 non-null  object
#  6   membership_category           36992 non-null  object
#  7   joining_date                  36992 non-null  object
#  8   joined_through_referral       36992 non-null  object
#  9   referral_id                   36992 non-null  object
#  10  preferred_offer_types         36704 non-null  object
#  11  medium_of_operation           36992 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                        0
# Name                               0
# age                                0
# gender                             0
# security_no                        0
# region_category                 5428
# membership_category                0
# joining_date                       0
# joined_through_referral            0
# referral_id                        0
# preferred_offer_types            288
# medium_of_operation                0
# internet_option                    0
# last_visit_time                    0
# days_since_last_login              0
# avg_time_spent                     0
# avg_transaction_value              0
# avg_frequency_login_days           0
# points_in_wallet                3443
# used_special_discount              0
# offer_application_preference       0
# past_complaint                     0
# complaint_status                   0
# feedback                           0
# churn_risk_score                   0
# dtype: int64

# %%
df.notnull().sum()/df.shape[0]*100
# percentage of the data which aren't missing
# Out:
# customer_id                     100.000000
# Name                            100.000000
# age                             100.000000
# gender                          100.000000
# security_no                     100.000000
# region_category                  85.326557
# membership_category             100.000000
# joining_date                    100.000000
# joined_through_referral         100.000000
# referral_id                     100.000000
# preferred_offer_types            99.221453
# medium_of_operation             100.000000
# internet_option                 100.000000
# last_visit_time                 100.000000
# days_since_last_login           100.000000
# avg_time_spent                  100.000000
# avg_transaction_value           100.000000
# avg_frequency_login_days        100.000000
# points_in_wallet                 90.692582
# used_special_discount           100.000000
# offer_application_preference    100.000000
# past_complaint                  100.000000
# ...

# %%
null_var=df.isnull().sum()/df.shape[0]*100
null_var
# percentage of the data which are missing
# Out:
# customer_id                      0.000000
# Name                             0.000000
# age                              0.000000
# gender                           0.000000
# security_no                      0.000000
# region_category                 14.673443
# membership_category              0.000000
# joining_date                     0.000000
# joined_through_referral          0.000000
# referral_id                      0.000000
# preferred_offer_types            0.778547
# medium_of_operation              0.000000
# internet_option                  0.000000
# last_visit_time                  0.000000
# days_since_last_login            0.000000
# avg_time_spent                   0.000000
# avg_transaction_value            0.000000
# avg_frequency_login_days         0.000000
# points_in_wallet                 9.307418
# used_special_discount            0.000000
# offer_application_preference     0.000000
# past_complaint                   0.000000
# ...

# %%
drop_col=null_var[null_var>5].keys()
drop_col
# dropping the columns which has missing values greater than 5%
# Out:
# Index(['region_category', 'points_in_wallet'], dtype='object')

# %%
dropped_col=df.drop(columns=drop_col)
dropped_col
# Out:
#                                 customer_id              Name  age gender  \
# 0          fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1      fffe43004900440032003100300035003700       Traci Peery   32      F
# 2          fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3      fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4      fffe43004900440031003900350030003600      Meghan Kosak   31      F
# ...                                     ...               ...  ...    ...
# 36987  fffe43004900440035003500390036003100          Cuc Tarr   46      F
# 36988  fffe43004900440033003500380036003600    Jenni Stronach   29      F
# 36989      fffe4300490044003500330034003100     Luciana Kinch   23      F
# 36990  fffe43004900440031003200390039003000     Tawana Ardoin   53      M
# 36991  fffe43004900440033003600340034003200  Verlene Beaulieu   35      M
#
#       security_no  membership_category joining_date joined_through_referral  \
# ...

# %%
dropped_col.shape
# Out:
# (36992, 23)

# %%
df.shape
# Out:
# (36992, 25)

# %%
sns.heatmap(dropped_col.isnull())
# Out:
# <Axes: >

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df3_row=dropped_col.dropna()
df3_row
# Out:
#                                 customer_id              Name  age gender  \
# 0          fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1      fffe43004900440032003100300035003700       Traci Peery   32      F
# 2          fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3      fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4      fffe43004900440031003900350030003600      Meghan Kosak   31      F
# ...                                     ...               ...  ...    ...
# 36987  fffe43004900440035003500390036003100          Cuc Tarr   46      F
# 36988  fffe43004900440033003500380036003600    Jenni Stronach   29      F
# 36989      fffe4300490044003500330034003100     Luciana Kinch   23      F
# 36990  fffe43004900440031003200390039003000     Tawana Ardoin   53      M
# 36991  fffe43004900440033003600340034003200  Verlene Beaulieu   35      M
#
#       security_no  membership_category joining_date joined_through_referral  \
# ...

# %%
sns.heatmap(df3_row.isnull())
# Out:
# <Axes: >

# %%
df3_row.isnull().sum()
# Out:
# customer_id                     0
# Name                            0
# age                             0
# gender                          0
# security_no                     0
# membership_category             0
# joining_date                    0
# joined_through_referral         0
# referral_id                     0
# preferred_offer_types           0
# medium_of_operation             0
# internet_option                 0
# last_visit_time                 0
# days_since_last_login           0
# avg_time_spent                  0
# avg_transaction_value           0
# avg_frequency_login_days        0
# used_special_discount           0
# offer_application_preference    0
# past_complaint                  0
# complaint_status                0
# feedback                        0
# churn_risk_score                0
# dtype: int64

# %%
d=df3_row.select_dtypes(include=['int64','float64']).columns
d1=df.select_dtypes(include=['int64','float64']).columns

d1
# Out:
# Index(['age', 'days_since_last_login', 'avg_time_spent',
#        'avg_transaction_value', 'points_in_wallet', 'churn_risk_score'],
#       dtype='object')

# %%
d
# Out:
# Index(['age', 'days_since_last_login', 'avg_time_spent',
#        'avg_transaction_value', 'churn_risk_score'],
#       dtype='object')

# %%
len(d1)
# Out:
# 6

# %%
for i ,var in enumerate(d):
    plt.subplot(3,2,i+1)
    sns.displot(df3_row[var],bins=30,color='b')
    sns.displot(df[var],bins=30,color='r')
    plt.show()

# %%
d1=df.select_dtypes(include=['object']).columns
d1
# Out:
# Index(['customer_id', 'Name', 'gender', 'security_no', 'region_category',
#        'membership_category', 'joining_date', 'joined_through_referral',
#        'referral_id', 'preferred_offer_types', 'medium_of_operation',
#        'internet_option', 'last_visit_time', 'avg_frequency_login_days',
#        'used_special_discount', 'offer_application_preference',
#        'past_complaint', 'complaint_status', 'feedback'],
#       dtype='object')

# %%
len(d1)
# Out:
# 19

# %%
missing_values=df.isnull().sum()/df.shape[0]*100
missing_values
# Out:
# customer_id                      0.000000
# Name                             0.000000
# age                              0.000000
# gender                           0.000000
# security_no                      0.000000
# region_category                 14.673443
# membership_category              0.000000
# joining_date                     0.000000
# joined_through_referral          0.000000
# referral_id                      0.000000
# preferred_offer_types            0.778547
# medium_of_operation              0.000000
# internet_option                  0.000000
# last_visit_time                  0.000000
# days_since_last_login            0.000000
# avg_time_spent                   0.000000
# avg_transaction_value            0.000000
# avg_frequency_login_days         0.000000
# points_in_wallet                 9.307418
# used_special_discount            0.000000
# offer_application_preference     0.000000
# past_complaint                   0.000000
# ...

# %%
to_be=missing_values[missing_values>10].keys()
to_be
# Out:
# Index(['region_category'], dtype='object')

# %%
dropped_col=df.drop(columns=to_be)

# %%
dropped_col
# Out:
#                                 customer_id              Name  age gender  \
# 0          fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1      fffe43004900440032003100300035003700       Traci Peery   32      F
# 2          fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3      fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4      fffe43004900440031003900350030003600      Meghan Kosak   31      F
# ...                                     ...               ...  ...    ...
# 36987  fffe43004900440035003500390036003100          Cuc Tarr   46      F
# 36988  fffe43004900440033003500380036003600    Jenni Stronach   29      F
# 36989      fffe4300490044003500330034003100     Luciana Kinch   23      F
# 36990  fffe43004900440031003200390039003000     Tawana Ardoin   53      M
# 36991  fffe43004900440033003600340034003200  Verlene Beaulieu   35      M
#
#       security_no  membership_category joining_date joined_through_referral  \
# ...

# %%
drop_raw=dropped_col
drop_raw
# Out:
#                                 customer_id              Name  age gender  \
# 0          fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1      fffe43004900440032003100300035003700       Traci Peery   32      F
# 2          fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3      fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4      fffe43004900440031003900350030003600      Meghan Kosak   31      F
# ...                                     ...               ...  ...    ...
# 36987  fffe43004900440035003500390036003100          Cuc Tarr   46      F
# 36988  fffe43004900440033003500380036003600    Jenni Stronach   29      F
# 36989      fffe4300490044003500330034003100     Luciana Kinch   23      F
# 36990  fffe43004900440031003200390039003000     Tawana Ardoin   53      M
# 36991  fffe43004900440033003600340034003200  Verlene Beaulieu   35      M
#
#       security_no  membership_category joining_date joined_through_referral  \
# ...

# %%
df3=drop_raw.select_dtypes(['int64','float64'])
df3
# Out:
#        age  days_since_last_login  avg_time_spent  avg_transaction_value  \
# 0       18                     17      300.630000               53005.25
# 1       32                     16      306.340000               12838.38
# 2       44                     14      516.160000               21027.00
# 3       37                     11       53.270000               25239.56
# 4       31                     20      113.130000               24483.66
# ...    ...                    ...             ...                    ...
# 36987   46                      2     -650.682759               27277.68
# 36988   29                     13     -638.123421               11069.71
# 36989   23                     12      154.940000               38127.56
# 36990   53                     15      482.610000                2378.86
# 36991   35                     15       79.180000                2189.68
#
#        points_in_wallet  churn_risk_score
# 0            781.750000                 2
# ...

# %%
sns.heatmap(df3.notnull())
# Out:
# <Axes: >

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df3.isnull().sum()
# Out:
# age                         0
# days_since_last_login       0
# avg_time_spent              0
# avg_transaction_value       0
# points_in_wallet         3443
# churn_risk_score            0
# dtype: int64

# %%
missing_var=[var for var in  df3.columns if df3[var].isnull().sum()>0]
missing_var
# finding the missing variable column from the dataset
# Out:
# ['points_in_wallet']

# %%
sns.set()
for i ,var in enumerate(missing_var):
    sns.displot(df3[var])
# finding the missing values int the diagram

# %%
df4=df3.fillna(df3.mean())
df4.isnull().sum().sum()
# Out:
# 0

# %%
df4.isnull().sum()
# Out:
# age                      0
# days_since_last_login    0
# avg_time_spent           0
# avg_transaction_value    0
# points_in_wallet         0
# churn_risk_score         0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# age                         0
# days_since_last_login       0
# avg_time_spent              0
# avg_transaction_value       0
# points_in_wallet         3443
# churn_risk_score            0
# dtype: int64

# %%
d=df4.keys()
d
# Out:
# Index(['age', 'days_since_last_login', 'avg_time_spent',
#        'avg_transaction_value', 'points_in_wallet', 'churn_risk_score'],
#       dtype='object')

# %%
len(d)
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
sns.set()
for i ,var in enumerate(d):
    plt.subplot(3,2,i+1)
    sns.displot(df4[var],color='r',label="Corrected")
    sns.displot(df[var],color='b',label='original')
    plt.legend()
# Out:
# C:\Users\shankar\AppData\Local\Temp\ipykernel_1172\1989607168.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,2,i+1)
# C:\Users\shankar\AppData\Local\Temp\ipykernel_1172\1989607168.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,2,i+1)
# C:\Users\shankar\AppData\Local\Temp\ipykernel_1172\1989607168.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,2,i+1)
# ...

# %%
plt.figure(figsize=(10,10))
sns.set()
for i ,var in enumerate(d):
    plt.subplot(3,2,i+1)
    sns.boxplot(df4[var],color='r')
    sns.boxplot(df[var],color='b')
    plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # new tutorial

# %%
new_df=df.select_dtypes(['object'])
new_df.shape
# Out:
# (36992, 19)

# %%
df.isnull().sum()
# Out:
# customer_id                        0
# Name                               0
# age                                0
# gender                             0
# security_no                        0
# region_category                 5428
# membership_category                0
# joining_date                       0
# joined_through_referral            0
# referral_id                        0
# preferred_offer_types            288
# medium_of_operation                0
# internet_option                    0
# last_visit_time                    0
# days_since_last_login              0
# avg_time_spent                     0
# avg_transaction_value              0
# avg_frequency_login_days           0
# points_in_wallet                3443
# used_special_discount              0
# offer_application_preference       0
# past_complaint                     0
# complaint_status                   0
# feedback                           0
# churn_risk_score                   0
# dtype: int64

# %%
df['region_category'].unique()
# Out:
# array(['Village', 'City', 'Town', nan], dtype=object)

# %%
"""
Signature:
df.fillna(
    value: 'Hashable | Mapping | Series | DataFrame' = None,
    *,
    method: 'FillnaOptions | None' = None,
    axis: 'Axis | None' = None,
    inplace: 'bool' = False,
    limit: 'int | None' = None,
    downcast: 'dict | None' = None,
) -> 'DataFrame | None'
Docstring:
Fill NA/NaN values using the specified method.

Parameters
----------
value : scalar, dict, Series, or DataFrame
    Value to use to fill holes (e.g. 0), alternately a
    dict/Series/DataFrame of values specifying which value to use for
    each index (for a Series) or column (for a DataFrame).  Values not
    in the dict/Series/DataFrame will not be filled. This value cannot
    be a list.
method : {'backfill', 'bfill', 'ffill', None}, default None
    Method to use for filling holes in reindexed Series:

    * ffill: propagate last valid observation forward to next valid.
    * backfill / bfill: use next valid observation to fill gap.

axis : {0 or 'index', 1 or 'columns'}
    Axis along which to fill missing values. For `Series`
    this parameter is unused and defaults to 0.
inplace : bool, default False
    If True, fill in-place. Note: this will modify any
    other views on this object (e.g., a no-copy slice for a column in a
    DataFrame).
limit : int, default None
    If method is specified, this is the maximum number of consecutive
    NaN values to forward/backward fill. In other words, if there is
    a gap with more than this number of consecutive NaNs, it will only
    be partially filled. If method is not specified, this is the
    maximum number of entries along the entire axis where NaNs will be
    filled. Must be greater than 0 if not None.
downcast : dict, default is None
    A dict of item->dtype of what to downcast if possible,
    or the string 'infer' which will try to downcast to an appropriate
    equal type (e.g. float64 to int64 if possible).

Returns
-------
DataFrame or None
    Object with missing values filled or None if ``inplace=True``.

See Also
--------
interpolate : Fill NaN values using interpolation.
reindex : Conform object to new index.
asfreq : Convert TimeSeries to specified frequency.

Examples
--------
>>> df = pd.DataFrame([[np.nan, 2, np.nan, 0],
...                    [3, 4, np.nan, 1],
...                    [np.nan, np.nan, np.nan, np.nan],
...                    [np.nan, 3, np.nan, 4]],
...                   columns=list("ABCD"))
>>> df
     A    B   C    D
0  NaN  2.0 NaN  0.0
1  3.0  4.0 NaN  1.0
2  NaN  NaN NaN  NaN
3  NaN  3.0 NaN  4.0

Replace all NaN elements with 0s.

>>> df.fillna(0)
     A    B    C    D
0  0.0  2.0  0.0  0.0
1  3.0  4.0  0.0  1.0
2  0.0  0.0  0.0  0.0
3  0.0  3.0  0.0  4.0

We can also propagate non-null values forward or backward.

>>> df.fillna(method="ffill")
     A    B   C    D
0  NaN  2.0 NaN  0.0
1  3.0  4.0 NaN  1.0
2  3.0  4.0 NaN  1.0
3  3.0  3.0 NaN  4.0

Replace all NaN elements in column 'A', 'B', 'C', and 'D', with 0, 1,
2, and 3 respectively.

>>> values = {"A": 0, "B": 1, "C": 2, "D": 3}
>>> df.fillna(value=values)
     A    B    C    D
0  0.0  2.0  2.0  0.0
1  3.0  4.0  2.0  1.0
2  0.0  1.0  2.0  3.0
3  0.0  3.0  2.0  4.0

Only replace the first NaN element.

>>> df.fillna(value=values, limit=1)
     A    B    C    D
0  0.0  2.0  2.0  0.0
1  3.0  4.0  NaN  1.0
2  NaN  1.0  NaN  3.0
3  NaN  3.0  NaN  4.0

When filling using a DataFrame, replacement happens along
the same column names and same indices

>>> df2 = pd.DataFrame(np.zeros((4, 4)), columns=list("ABCE"))
>>> df.fillna(df2)
     A    B    C    D
0  0.0  2.0  0.0  0.0
1  3.0  4.0  0.0  1.0
2  0.0  0.0  0.0  NaN
3  0.0  3.0  0.0  4.0

Note that column D is not affected since it is not present in df2.
File:      c:\users\shankar\appdata\local\programs\python\python311\lib\site-packages\pandas\core\frame.py
Type:      method
"""
# Out:
#   Cell In[45], line 125
#     """
#        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 3724-3725: truncated \uXXXX escape

# %%
df
# Out:
#                                 customer_id              Name  age gender  \
# 0          fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1      fffe43004900440032003100300035003700       Traci Peery   32      F
# 2          fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3      fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4      fffe43004900440031003900350030003600      Meghan Kosak   31      F
# ...                                     ...               ...  ...    ...
# 36987  fffe43004900440035003500390036003100          Cuc Tarr   46      F
# 36988  fffe43004900440033003500380036003600    Jenni Stronach   29      F
# 36989      fffe4300490044003500330034003100     Luciana Kinch   23      F
# 36990  fffe43004900440031003200390039003000     Tawana Ardoin   53      M
# 36991  fffe43004900440033003600340034003200  Verlene Beaulieu   35      M
#
#       security_no region_category  membership_category joining_date  \
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                        0
# Name                               0
# age                                0
# gender                             0
# security_no                        0
# region_category                 5428
# membership_category                0
# joining_date                       0
# joined_through_referral            0
# referral_id                        0
# preferred_offer_types            288
# medium_of_operation                0
# internet_option                    0
# last_visit_time                    0
# days_since_last_login              0
# avg_time_spent                     0
# avg_transaction_value              0
# avg_frequency_login_days           0
# points_in_wallet                3443
# used_special_discount              0
# offer_application_preference       0
# past_complaint                     0
# complaint_status                   0
# feedback                           0
# churn_risk_score                   0
# dtype: int64

# %% [markdown]
# # Scikit learn starting

# %%
from sklearn.impute import SimpleImputer

# %%
test=pd.read_csv(r"C:\\Users\\shankar\\Downloads\\testhouse.csv")
train=pd.read_csv(r"C:\\Users\\shankar\\Downloads\\trainhouse.csv")

# %%
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
test.shape
# Out:
# (1459, 80)

# %%
train.shape
# Out:
# (1460, 81)

# %%
X_train=train.drop(columns='SalePrice')  
# dropping the sale column so that target variable shouldn't be there
# X is capital in that variable because it is matrix there
# y is lowercase because it is vector according to notation of machine learning 
y_train=train['SalePrice']

# %%
y_train.shape
# Out:
# (1460,)
